# %% [markdown]
# # Transformations

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>The transformations library has been deprecated.</b> Please refer to the <a href="https://orbax.readthedocs.io/en/latest/guides/checkpoint/checkpointing_pytrees.html#partial-restore">Partial Restoration</a> documentation for information on how to restore only part of a PyTree within a checkpoint.
# </div>
