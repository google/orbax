# %% [markdown]
# # Orbax v0 to v1 Migration Guide

# %% [markdown]
# ## How to use v1 API to load checkpoints saved with v0 API

# %% [markdown]
# v1 `loading` API can load checkpoints saved with v0 API. But before discussing the details, let us first understand how saved checkpoints are laid out.

# %% [markdown]
# ### Checkpoint Layout

# %% [markdown]
# Most commonly, Orbax saves a checkpoint in a directory, which in turn contains subdirectories containing checkpointables (items).
#
# e.g. The checkpoint in **step_1234** contains checkpointables in subdirectories named as **state** and **my_json_data**.
#
# ```
# root_dir/
#     step_1234/
#         _CHECKPOINT_METADATA
#         state/
#             _METADATA
#             manifest.ocdbt
#             ocdbt.process_0/
#         pytree/
#             _METADATA
#             manifest.ocdbt
#             ocdbt.process_0/
#         my_json_data/
#             my_data.json
# ```
# `CheckpointManager` and `CompositeCheckpointHandler` save checkpoints the above layout.

# %% [markdown]
# Alternatively, users can save checkpoints directly to a directory without any checkpointables (subdirectory).
#
# e.g. The following layout contains an array checkpoint without any names like `state` as above.
# ```
# my_checkpoint/
#         _CHECKPOINT_METADATA
#         _METADATA
#         manifest.ocdbt
#         ocdbt.process_0/
# ```
# v0 `Checkpointer` (without `CompositeCheckpointHandler`) can be used to save in such layouts.

# %% [markdown]
# ### Compatibility Matrix

# %% [markdown]
# #### Loading array checkpoint with `load_pytree(...)`

# %% [markdown]
# | Restore API | Response
# :------- | :-------- |
# |loading.load_pytree(`root_dir`)|Error: expecting a subdir named `pytree`|
# |loading.load_pytree(`step_1234`)|Loads checkpointable under subdirectory, `pytree`|
# |loading.load_pytree(`my_checkpoint`)|Error: expecting a subdir named `pytree`|
# |loading.load_pytree(`root_dir`, `checkpointable_name='pytree'`)|Error: expecting a subdir named `pytree`|
# |loading.load_pytree(`step_1234`, `checkpointable_name='state'`)|Loads checkpointable under subdirectory, `state`|
# |loading.load_pytree(`step_1234`, `checkpointable_name='pytree'`)|Loads checkpointable under subdirectory, `pytree`|
# |loading.load_pytree(`my_checkpoint`, `checkpointable_name='pytree'`)|Error: expecting a subdir named `pytree`|
# |loading.load_pytree(`root_dir`, `checkpointable_name=None`)|Error: expecting pytree metadata file|
# |loading.load_pytree(`step_1234`, `checkpointable_name=None`)|Error: expecting pytree metadata file|
# |loading.load_pytree(`my_checkpoint`, `checkpointable_name=None`)|Loads checkpoint from `my_checkpoint`|

# %% [markdown]
# #### Loading checkpointables with `load_checkpointables(...)`

# %% [markdown]
# | Restore API | Response
# :------- | :-------- |
# |loading.load_checkpointables(`root_dir`)|Error: suggesting to try a subdir instead|
# |loading.load_checkpointables(`step_1234`)|Loads all checkpointables from respective subdirs|
# |loading.load_checkpointables(`my_checkpoint`)|Error: suggesting to use load_pytree instead|
# |loading.load_checkpointables(`root_dir`, `dict(state=abstract_tree, pytree=abstract_tree)`)|Error: suggesting to try a subdir instead|
# |loading.load_checkpointables(`step_1234`, `dict(state=abstract_tree, my_json_data=None)`)|Loads `state` and `my_json_data` checkpointables from respective subdirs|
# |loading.load_checkpointables(`my_checkpoint`, `dict(state=abstract_tree, pytree=abstract_tree)`)|Error: suggesting to use load_pytree instead|
